# %%
import sys
import os
import itertools
sys.path.append(os.path.abspath('../'))
from manticore_handler import manticore_handler

# %%
m = manticore_handler('boundedStackFixed.sol')
# Out:
# # -- Deploying Contract boundedStackFixed.sol
# # -- Deploying Contract boundedStackFixed.sol
# ---------------------------------------------------------------------------
# EthereumError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 m = manticore_handler('boundedStackFixed.sol')
#
# File ~/BIIC/manticore-predicate-abstraction/manticore_handler.py:17, in manticore_handler.__init__(self, url, outputspace, workspace, contract_name)
#      13     outputspace = url + "_results"
#      14 self.manticore = ManticoreEVM(
#      15     workspace_url=workspace, outputspace_url="fs:"+outputspace)
# ---> 17 self._initAccountsAndContract(url, contract_name)
#      18 self._initContractSelectorsAndMetadata()
#      19 self._initBlockchain()
#
# File ~/BIIC/manticore-predicate-abstraction/manticore_handler.py:26, in manticore_handler._initAccountsAndContract(self, url, contract_name)
#      24 self._initAccounts()
#      25 print(f"# -- Deploying Contract {url}")
# ---> 26 self.working_contract = self.add_contract(url, contract_name)
#
# File ~/BIIC/manticore-predicate-abstraction/manticore_handler.py:250, in manticore_handler.add_contract(self, url, contract_name, args, owner, balance)
#     248 if owner is None:
#     249     owner = self.owner_account
# --> 250 new_contract = self.manticore.solidity_create_contract(
#     251     source_code, owner=owner, args=args, contract_name=contract_name, balance=balance)
#     252 end = time.time()
#     253 assert (
#     254     new_contract is not None), "Problemas en el creado del contrato"
#
# File ~/BIIC/manticore-predicate-abstraction/venv/lib/python3.10/site-packages/manticore/ethereum/manticore.py:620, in ManticoreEVM.solidity_create_contract(self, source_code, owner, name, contract_name, libraries, balance, address, args, gas, compile_args)
#     616 if not must_have_balance:
#     617     # balance always != 0
#     619     if not md.constructor_abi['stateMutability'] == 'payable':
# --> 620         raise EthereumError(
#     621             f"Can't create solidity contract with balance ({balance}) "
#     622             f"different than 0 because the contract's constructor is not payable."
#     623         )
#     625 for state in self.ready_states:
#     626     world = state.platform
#
# EthereumError: Can't create solidity contract with balance (None) different than 0 because the contract's constructor is not payable.

# %%
metodos = ["push","pop"]
precondiciones = [x+"_precondition" for x in metodos]
def call_pre():
    for cond in precondiciones:
        m.callContractFunction(cond,tx_sender=m.witness_account)

# %%
states = list(itertools.product([0,1],repeat=len(metodos)))
def repr_state(state):
    text = ""
    for x,method in zip(state,metodos):
        text += '_'+method if x else ""
    if text == "":
        text = "vacio"
    return text

# %%
call_pre()

# %%
found = []
for state in states:
    count = m.generateTestCases(keys=precondiciones,
                                targets=state,
                                testcaseName=f"STATE_{repr_state(state)}");
    if count > 0:
        found.append(f"found {count} testcases that reach {repr_state(state)} initial state")
    else:
        found.append(f"found no testcases for {repr_state(state)} initial state")
# Out:
# (level _is_sat_z3_call) took 0.00631403923034668 seconds (unsat)
# (level solver.can_be_true) took 0.013813018798828125 seconds
# (level state.can_be_true) took 0.015081644058227539 seconds
# (level _is_sat_z3_call) took 0.003448009490966797 seconds (unsat)
# (level solver.can_be_true) took 0.005707502365112305 seconds
# (level state.can_be_true) took 0.006021261215209961 seconds
# (level _is_sat_z3_call) took 0.0033652782440185547 seconds (unsat)
# (level solver.can_be_true) took 0.005574226379394531 seconds
# (level state.can_be_true) took 0.005856037139892578 seconds
# (level _is_sat_z3_call) took 0.010898828506469727 seconds (sat)
# (level solver.can_be_true) took 0.012975692749023438 seconds
# (level state.can_be_true) took 0.013246774673461914 seconds
# (level _is_sat_z3_call) took 0.010677814483642578 seconds (sat)
# (level solver.can_be_true) took 0.012181282043457031 seconds
# (level state.can_be_true) took 0.01218867301940918 seconds
# (level solver.can_be_true) took 0.00017976760864257812 seconds
# (level state.can_be_true) took 0.00019884109497070312 seconds
# (level _is_sat_z3_call) took 0.0013887882232666016 seconds (sat)
# (level get_value_in_batch) took 0.002881288528442383 seconds
# (level solve_one_n_batched) took 0.002923250198364258 seconds
# (level _is_sat_z3_call) took 0.018419504165649414 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0002288818359375 seconds
# (level _getvalue_all) took 0.0002586841583251953 seconds)
# (level get_value_in_batch) took 0.022748708724975586 seconds
# (level solve_one_n_batched) took 0.025215625762939453 seconds
# (level _is_sat_z3_call) took 0.0013456344604492188 seconds (sat)
# (level get_value_in_batch) took 0.0030961036682128906 seconds
# (level solve_one_n_batched) took 0.003103971481323242 seconds
# (level _is_sat_z3_call) took 0.0012297630310058594 seconds (sat)
# (level get_value_in_batch) took 0.003113269805908203 seconds
# (level solve_one_n_batched) took 0.003157377243041992 seconds
# (level _is_sat_z3_call) took 0.0014390945434570312 seconds (sat)
# (level get_value_in_batch) took 0.003225088119506836 seconds
# (level solve_one_n_batched) took 0.0032799243927001953 seconds
# (level _is_sat_z3_call) took 0.0015473365783691406 seconds (sat)
# (level get_value_in_batch) took 0.0035920143127441406 seconds
# (level solve_one_n_batched) took 0.00360107421875 seconds
# (level _is_sat_z3_call) took 0.0015325546264648438 seconds (sat)
# (level get_value_in_batch) took 0.0034215450286865234 seconds
# (level solve_one_n_batched) took 0.003492593765258789 seconds
# (level _is_sat_z3_call) took 0.0019071102142333984 seconds (sat)
# (level get_value_in_batch) took 0.0036971569061279297 seconds
# (level solve_one_n_batched) took 0.003749847412109375 seconds
# (level _is_sat_z3_call) took 0.0018475055694580078 seconds (sat)
# (level get_value_in_batch) took 0.004880666732788086 seconds
# (level solve_one_n_batched) took 0.004891872406005859 seconds
# (level _is_sat_z3_call) took 0.001409769058227539 seconds (sat)
# (level get_value_in_batch) took 0.003000974655151367 seconds
# (level solve_one_n_batched) took 0.0030417442321777344 seconds
# (level _is_sat_z3_call) took 0.0012402534484863281 seconds (sat)
# (level get_value_in_batch) took 0.0027551651000976562 seconds
# (level solve_one_n_batched) took 0.002794981002807617 seconds
# (level _is_sat_z3_call) took 0.002359628677368164 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00019598007202148438 seconds
# (level _getvalue_all) took 0.00023293495178222656 seconds)
# (level get_value_in_batch) took 0.004941701889038086 seconds
# (level solve_one_n_batched) took 0.005917549133300781 seconds
# (level _is_sat_z3_call) took 0.00127410888671875 seconds (sat)
# (level get_value_in_batch) took 0.002801656723022461 seconds
# (level solve_one_n_batched) took 0.0029397010803222656 seconds
# (level _is_sat_z3_call) took 0.2538144588470459 seconds (sat)
# (level _getvalue_all_z3_call) took 0.013264894485473633 seconds
# (level _getvalue_all) took 0.014260530471801758 seconds)
# (level get_value_in_batch) took 7.5957350730896 seconds
# (level solve_one_n_batched) took 7.618281841278076 seconds
# (level _is_sat_z3_call) took 0.2912304401397705 seconds (sat)
# (level _getvalue_all_z3_call) took 0.23162531852722168 seconds
# (level _getvalue_all) took 0.23361444473266602 seconds)
# (level get_value_in_batch) took 16.34391450881958 seconds
# (level solve_one_n_batched) took 16.373500108718872 seconds
# (level _is_sat_z3_call) took 0.23123478889465332 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0009756088256835938 seconds
# (level _getvalue_all) took 0.0010404586791992188 seconds)
# (level get_value_in_batch) took 0.26163697242736816 seconds
# (level solve_one_n_batched) took 0.26265573501586914 seconds
# (level _is_sat_z3_call) took 0.003377199172973633 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005562305450439453 seconds
# (level _getvalue_all) took 0.0006201267242431641 seconds)
# (level get_value_in_batch) took 0.013491392135620117 seconds
# (level solve_one_n_batched) took 0.014325857162475586 seconds
# (level _is_sat_z3_call) took 0.0027747154235839844 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0004703998565673828 seconds
# (level _getvalue_all) took 0.0005245208740234375 seconds)
# (level get_value_in_batch) took 0.01170659065246582 seconds
# (level solve_one_n_batched) took 0.012525320053100586 seconds
# (level _is_sat_z3_call) took 0.002674579620361328 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00046515464782714844 seconds
# (level _getvalue_all) took 0.0005183219909667969 seconds)
# (level get_value_in_batch) took 0.011529922485351562 seconds
# (level solve_one_n_batched) took 0.012312650680541992 seconds
# (level 3) took 24.394341230392456 seconds
# (level _is_sat_z3_call) took 0.0015156269073486328 seconds (sat)
# (level _getvalue_all_z3_call) took 8.463859558105469e-05 seconds
# (level _getvalue_all) took 0.00010585784912109375 seconds)
# (level get_value_in_batch) took 0.002886056900024414 seconds
# (level solve_one_n_batched) took 0.002935171127319336 seconds
# -Concrete value for initial_block : 0
# (level _is_sat_z3_call) took 0.0034821033477783203 seconds (unsat)
# (level solver.can_be_true) took 0.005629539489746094 seconds
# (level state.can_be_true) took 0.005899190902709961 seconds
# (level _is_sat_z3_call) took 0.0034639835357666016 seconds (unsat)
# (level solver.can_be_true) took 0.005578756332397461 seconds
# (level state.can_be_true) took 0.005946159362792969 seconds
# (level _is_sat_z3_call) took 0.0037865638732910156 seconds (unsat)
# (level solver.can_be_true) took 0.00613713264465332 seconds
# (level state.can_be_true) took 0.006403207778930664 seconds
# (level _is_sat_z3_call) took 0.0034837722778320312 seconds (unsat)
# (level solver.can_be_true) took 0.005697727203369141 seconds
# (level state.can_be_true) took 0.0059642791748046875 seconds
# (level _is_sat_z3_call) took 0.0034685134887695312 seconds (unsat)
# (level solver.can_be_true) took 0.00563502311706543 seconds
# (level state.can_be_true) took 0.005900144577026367 seconds
# (level _is_sat_z3_call) took 0.0033469200134277344 seconds (unsat)
# (level solver.can_be_true) took 0.005404472351074219 seconds
# (level state.can_be_true) took 0.005675792694091797 seconds
# (level _is_sat_z3_call) took 0.004515647888183594 seconds (unsat)
# (level solver.can_be_true) took 0.007333517074584961 seconds
# (level state.can_be_true) took 0.0076732635498046875 seconds
# (level _is_sat_z3_call) took 0.011377334594726562 seconds (sat)
# (level solver.can_be_true) took 0.013508319854736328 seconds
# (level state.can_be_true) took 0.013777494430541992 seconds
# (level _is_sat_z3_call) took 0.010936737060546875 seconds (sat)
# (level solver.can_be_true) took 0.012573480606079102 seconds
# (level state.can_be_true) took 0.012581110000610352 seconds
# (level solver.can_be_true) took 0.00017833709716796875 seconds
# (level state.can_be_true) took 0.00019669532775878906 seconds
# (level _is_sat_z3_call) took 0.0014810562133789062 seconds (sat)
# (level get_value_in_batch) took 0.0029654502868652344 seconds
# (level solve_one_n_batched) took 0.0030090808868408203 seconds
# (level _is_sat_z3_call) took 0.01839160919189453 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00023484230041503906 seconds
# (level _getvalue_all) took 0.00027108192443847656 seconds)
# (level get_value_in_batch) took 0.022646188735961914 seconds
# (level solve_one_n_batched) took 0.025035381317138672 seconds
# (level _is_sat_z3_call) took 0.0013890266418457031 seconds (sat)
# (level get_value_in_batch) took 0.0029718875885009766 seconds
# (level solve_one_n_batched) took 0.002979755401611328 seconds
# (level _is_sat_z3_call) took 0.0014581680297851562 seconds (sat)
# (level get_value_in_batch) took 0.0029370784759521484 seconds
# (level solve_one_n_batched) took 0.0029718875885009766 seconds
# (level _is_sat_z3_call) took 0.0012292861938476562 seconds (sat)
# (level get_value_in_batch) took 0.0026786327362060547 seconds
# (level solve_one_n_batched) took 0.002710580825805664 seconds
# (level _is_sat_z3_call) took 0.0012362003326416016 seconds (sat)
# (level get_value_in_batch) took 0.002668619155883789 seconds
# (level solve_one_n_batched) took 0.0026764869689941406 seconds
# (level _is_sat_z3_call) took 0.0012545585632324219 seconds (sat)
# (level get_value_in_batch) took 0.0027742385864257812 seconds
# (level solve_one_n_batched) took 0.0028085708618164062 seconds
# (level _is_sat_z3_call) took 0.001194000244140625 seconds (sat)
# (level get_value_in_batch) took 0.002600431442260742 seconds
# (level solve_one_n_batched) took 0.00263214111328125 seconds
# (level _is_sat_z3_call) took 0.0012056827545166016 seconds (sat)
# (level get_value_in_batch) took 0.0026273727416992188 seconds
# (level solve_one_n_batched) took 0.0026345252990722656 seconds
# (level _is_sat_z3_call) took 0.0012733936309814453 seconds (sat)
# (level get_value_in_batch) took 0.002701997756958008 seconds
# (level solve_one_n_batched) took 0.0027358531951904297 seconds
# (level _is_sat_z3_call) took 0.0012056827545166016 seconds (sat)
# (level get_value_in_batch) took 0.002604961395263672 seconds
# (level solve_one_n_batched) took 0.002638101577758789 seconds
# (level _is_sat_z3_call) took 0.0022287368774414062 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00018167495727539062 seconds
# (level _getvalue_all) took 0.00021576881408691406 seconds)
# (level get_value_in_batch) took 0.004750490188598633 seconds
# (level solve_one_n_batched) took 0.005854606628417969 seconds
# (level _is_sat_z3_call) took 0.0012378692626953125 seconds (sat)
# (level get_value_in_batch) took 0.0026824474334716797 seconds
# (level solve_one_n_batched) took 0.002821207046508789 seconds
# (level _is_sat_z3_call) took 0.25287818908691406 seconds (sat)
# (level _getvalue_all_z3_call) took 0.012939691543579102 seconds
# (level _getvalue_all) took 0.013849973678588867 seconds)
# (level get_value_in_batch) took 7.631314039230347 seconds
# (level solve_one_n_batched) took 7.653700113296509 seconds
# (level _is_sat_z3_call) took 0.2919485569000244 seconds (sat)
# (level _getvalue_all_z3_call) took 0.179518461227417 seconds
# (level _getvalue_all) took 0.18145990371704102 seconds)
# (level get_value_in_batch) took 16.636330366134644 seconds
# (level solve_one_n_batched) took 16.66642713546753 seconds
# (level _is_sat_z3_call) took 0.22908663749694824 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0011048316955566406 seconds
# (level _getvalue_all) took 0.0011734962463378906 seconds)
# (level get_value_in_batch) took 0.25578856468200684 seconds
# (level solve_one_n_batched) took 0.2567729949951172 seconds
# (level _is_sat_z3_call) took 0.002867460250854492 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005233287811279297 seconds
# (level _getvalue_all) took 0.0005805492401123047 seconds)
# (level get_value_in_batch) took 0.012544393539428711 seconds
# (level solve_one_n_batched) took 0.013399839401245117 seconds
# (level _is_sat_z3_call) took 0.0027794837951660156 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0004668235778808594 seconds
# (level _getvalue_all) took 0.0005233287811279297 seconds)
# (level get_value_in_batch) took 0.011651277542114258 seconds
# (level solve_one_n_batched) took 0.012448310852050781 seconds
# (level _is_sat_z3_call) took 0.0026912689208984375 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0004603862762451172 seconds
# (level _getvalue_all) took 0.0005142688751220703 seconds)
# (level get_value_in_batch) took 0.011524200439453125 seconds
# (level solve_one_n_batched) took 0.01232004165649414 seconds
# (level 3) took 24.709255933761597 seconds
# (level _is_sat_z3_call) took 0.0014717578887939453 seconds (sat)
# (level _getvalue_all_z3_call) took 8.416175842285156e-05 seconds
# (level _getvalue_all) took 0.00010418891906738281 seconds)
# (level get_value_in_batch) took 0.0027685165405273438 seconds
# (level solve_one_n_batched) took 0.0028197765350341797 seconds
# -Concrete value for initial_block : 0
# (level _is_sat_z3_call) took 0.003509998321533203 seconds (unsat)
# (level solver.can_be_true) took 0.005640745162963867 seconds
# (level state.can_be_true) took 0.005908012390136719 seconds
# (level _is_sat_z3_call) took 0.0034885406494140625 seconds (unsat)
# (level solver.can_be_true) took 0.0056858062744140625 seconds
# (level state.can_be_true) took 0.006003141403198242 seconds
# (level _is_sat_z3_call) took 0.003481149673461914 seconds (unsat)
# (level solver.can_be_true) took 0.005686521530151367 seconds
# (level state.can_be_true) took 0.0059528350830078125 seconds
# (level _is_sat_z3_call) took 0.003337860107421875 seconds (unsat)
# (level solver.can_be_true) took 0.00552678108215332 seconds
# (level state.can_be_true) took 0.005795955657958984 seconds

# %%
for line in found:
    print(line)
# Out:
# found no testcases for vacio initial state
# found no testcases for _isEmpty initial state
# found no testcases for _top initial state
# found 1 testcases that reach _top_isEmpty initial state
# found no testcases for _pop initial state
# found no testcases for _pop_isEmpty initial state
# found no testcases for _pop_top initial state
# found no testcases for _pop_top_isEmpty initial state
# found no testcases for _push initial state
# found no testcases for _push_isEmpty initial state
# found no testcases for _push_top initial state
# found 1 testcases that reach _push_top_isEmpty initial state
# found no testcases for _push_pop initial state
# found no testcases for _push_pop_isEmpty initial state
# found no testcases for _push_pop_top initial state
# found no testcases for _push_pop_top_isEmpty initial state

# %%
m.take_snapshot()
m.callContractFunction("push")
call_pre()
# Out:
# (level _is_sat_z3_call) took 0.0034847259521484375 seconds (sat)
# (level _getvalue_z3_call) took 0.00014090538024902344 seconds
# (level _is_sat_z3_call) took 0.0002639293670654297 seconds (sat)
# (level _getvalue_z3_call) took 0.000102996826171875 seconds
# (level _is_sat_z3_call) took 0.0002377033233642578 seconds (sat)
# (level _getvalue_z3_call) took 9.942054748535156e-05 seconds
# (level _is_sat_z3_call) took 0.0001552104949951172 seconds (unsat)
# (level _is_sat_z3_call) took 0.2335214614868164 seconds (sat)
# (level _is_sat_z3_call) took 0.010259628295898438 seconds (sat)
# (level _getvalue_z3_call) took 0.005261421203613281 seconds
# (level _is_sat_z3_call) took 0.03069162368774414 seconds (unsat)
# (level _is_sat_z3_call) took 0.010297060012817383 seconds (sat)
# (level _getvalue_z3_call) took 0.11719131469726562 seconds
# (level _is_sat_z3_call) took 0.010354757308959961 seconds (unsat)
# (level _is_sat_z3_call) took 0.02042984962463379 seconds (sat)
# (level _getvalue_z3_call) took 0.005265474319458008 seconds
# (level _is_sat_z3_call) took 0.040923357009887695 seconds (unsat)
# (level _is_sat_z3_call) took 0.03055858612060547 seconds (sat)
# (level _getvalue_z3_call) took 0.015371084213256836 seconds
# (level _is_sat_z3_call) took 0.015325784683227539 seconds (unsat)
# (level _is_sat_z3_call) took 0.010295629501342773 seconds (sat)
# (level _getvalue_z3_call) took 0.015417337417602539 seconds
# (level _is_sat_z3_call) took 0.02046370506286621 seconds (unsat)
# (level _is_sat_z3_call) took 0.030708789825439453 seconds (sat)
# (level _getvalue_z3_call) took 0.03573346138000488 seconds
# (level _is_sat_z3_call) took 0.03072190284729004 seconds (unsat)
# (level _is_sat_z3_call) took 0.2195124626159668 seconds (sat)
# (level _getvalue_z3_call) took 0.033006906509399414 seconds
# (level _is_sat_z3_call) took 0.02979898452758789 seconds (unsat)
# (level _is_sat_z3_call) took 0.015015363693237305 seconds (sat)
# (level _getvalue_z3_call) took 0.003930091857910156 seconds
# (level _is_sat_z3_call) took 0.01021432876586914 seconds (unsat)
# (level _is_sat_z3_call) took 0.005563020706176758 seconds (sat)
# (level _getvalue_z3_call) took 0.010464191436767578 seconds
# (level _is_sat_z3_call) took 0.010278463363647461 seconds (unsat)
# (level _is_sat_z3_call) took 0.032990217208862305 seconds (sat)
# (level _getvalue_z3_call) took 0.015468120574951172 seconds
# (level _is_sat_z3_call) took 0.041622161865234375 seconds (unsat)
# (level _is_sat_z3_call) took 0.27703332901000977 seconds (sat)
# (level _getvalue_z3_call) took 0.015502452850341797 seconds
# (level _is_sat_z3_call) took 0.010406494140625 seconds (unsat)
# (level _is_sat_z3_call) took 0.021109580993652344 seconds (sat)
# (level _getvalue_z3_call) took 0.010272026062011719 seconds
# (level _is_sat_z3_call) took 0.008408546447753906 seconds (unsat)
# (level _is_sat_z3_call) took 0.20874238014221191 seconds (sat)
# (level _getvalue_z3_call) took 0.011191606521606445 seconds
# (level _is_sat_z3_call) took 0.01023721694946289 seconds (sat)
# (level _is_sat_z3_call) took 0.037514686584472656 seconds (unsat)
# (level _getvalue_z3_call) took 0.20931100845336914 seconds
# (level _is_sat_z3_call) took 0.02551412582397461 seconds (unsat)
# (level _is_sat_z3_call) took 0.20447111129760742 seconds (sat)
# (level _getvalue_z3_call) took 0.010640382766723633 seconds
# (level _is_sat_z3_call) took 0.005276918411254883 seconds (unsat)
# (level _is_sat_z3_call) took 0.025856494903564453 seconds (sat)
# (level _getvalue_z3_call) took 0.014316320419311523 seconds
# (level _is_sat_z3_call) took 0.005188941955566406 seconds (sat)
# (level _getvalue_z3_call) took 0.008702993392944336 seconds
# (level _is_sat_z3_call) took 0.010231494903564453 seconds (unsat)
# (level _is_sat_z3_call) took 0.011081218719482422 seconds (sat)
# (level _getvalue_z3_call) took 0.0004019737243652344 seconds
# (level _is_sat_z3_call) took 0.0033173561096191406 seconds (unsat)
# (level _is_sat_z3_call) took 0.22115445137023926 seconds (sat)
# (level _getvalue_z3_call) took 0.0005698204040527344 seconds
# (level _is_sat_z3_call) took 0.02557516098022461 seconds (unsat)
# (level _is_sat_z3_call) took 0.05101203918457031 seconds (sat)
# (level _getvalue_z3_call) took 0.02043771743774414 seconds
# (level _is_sat_z3_call) took 0.018505334854125977 seconds (unsat)
# (level _is_sat_z3_call) took 0.041933536529541016 seconds (sat)(level _is_sat_z3_call) took 0.025992870330810547 seconds (sat)
#
# (level _getvalue_z3_call) took 0.015380620956420898 seconds
# (level _getvalue_z3_call) took 0.02571725845336914 seconds
# (level _is_sat_z3_call) took 0.005226612091064453 seconds (unsat)
# (level _is_sat_z3_call) took 0.010847091674804688 seconds (unsat)
# (level _is_sat_z3_call) took 0.19978642463684082 seconds (sat)
# (level _getvalue_z3_call) took 0.01712775230407715 seconds
# (level _is_sat_z3_call) took 0.01079869270324707 seconds (unsat)
# (level _is_sat_z3_call) took 0.006104469299316406 seconds (sat)
# (level _getvalue_z3_call) took 0.00012612342834472656 seconds
# (level _is_sat_z3_call) took 0.01030731201171875 seconds (unsat)
# (level _is_sat_z3_call) took 0.015377521514892578 seconds (sat)
# (level _getvalue_z3_call) took 0.02043008804321289 seconds
# (level _is_sat_z3_call) took 0.005188703536987305 seconds (unsat)
# (level _is_sat_z3_call) took 0.004277944564819336 seconds (sat)
# (level _getvalue_z3_call) took 0.00011754035949707031 seconds
# (level _is_sat_z3_call) took 0.0001704692840576172 seconds (unsat)
# (level _is_sat_z3_call) took 0.004807949066162109 seconds (sat)
# (level _getvalue_z3_call) took 0.0002732276916503906 seconds
# (level _is_sat_z3_call) took 0.00011873245239257812 seconds (unsat)
# (level _is_sat_z3_call) took 0.25418710708618164 seconds (sat)
# (level _getvalue_z3_call) took 0.004621267318725586 seconds
# (level _is_sat_z3_call) took 0.004402637481689453 seconds (unsat)
# (level _is_sat_z3_call) took 0.006417274475097656 seconds (sat)
# (level _getvalue_z3_call) took 0.00028634071350097656 seconds
# (level _is_sat_z3_call) took 0.00022530555725097656 seconds (unsat)
# (level _is_sat_z3_call) took 0.005735158920288086 seconds (sat)
# (level _getvalue_z3_call) took 0.00010967254638671875 seconds
# (level _is_sat_z3_call) took 0.00013256072998046875 seconds (unsat)
# (level _is_sat_z3_call) took 0.234205961227417 seconds (sat)
# (level _getvalue_z3_call) took 0.015531539916992188 seconds
# (level _is_sat_z3_call) took 0.015285015106201172 seconds (unsat)
# (level _is_sat_z3_call) took 0.21457147598266602 seconds (sat)
# (level _getvalue_z3_call) took 0.005579471588134766 seconds
# (level _is_sat_z3_call) took 0.0002665519714355469 seconds (unsat)
# (level _is_sat_z3_call) took 0.010231494903564453 seconds (sat)
# (level _getvalue_z3_call) took 0.010201692581176758 seconds
# (level _is_sat_z3_call) took 0.005110502243041992 seconds (sat)
# (level _getvalue_z3_call) took 0.015286922454833984 seconds
# (level _is_sat_z3_call) took 0.015271663665771484 seconds (unsat)
# (level _is_sat_z3_call) took 0.25635218620300293 seconds (sat)
# (level _getvalue_z3_call) took 0.016199588775634766 seconds
# (level _is_sat_z3_call) took 0.0009016990661621094 seconds (unsat)
# (level _is_sat_z3_call) took 0.01618027687072754 seconds (sat)
# (level _getvalue_z3_call) took 0.010521888732910156 seconds
# (level _is_sat_z3_call) took 0.010365724563598633 seconds (unsat)
# (level _is_sat_z3_call) took 0.2237849235534668 seconds (sat)
# (level _getvalue_z3_call) took 0.0005791187286376953 seconds
# (level _is_sat_z3_call) took 0.0012969970703125 seconds (sat)
# (level _getvalue_z3_call) took 0.00043582916259765625 seconds
# (level _is_sat_z3_call) took 0.0003192424774169922 seconds (unsat)
# (level _is_sat_z3_call) took 0.2195274829864502 seconds (sat)
# (level _getvalue_z3_call) took 0.01044321060180664 seconds
# (level _is_sat_z3_call) took 0.015325784683227539 seconds (unsat)
# (level _is_sat_z3_call) took 0.27086567878723145 seconds (sat)
# (level _is_sat_z3_call) took 0.45205235481262207 seconds (sat)
# (level _is_sat_z3_call) took 0.3843517303466797 seconds (sat)
# (level _is_sat_z3_call) took 0.3939402103424072 seconds (sat)

# %%
def repr_transition(state1,state2,metodo):
    return f"{repr_state(state1)}->{metodo}->{repr_state(state2)}"

# %%
ini_state = (1,0) #_push
found = []
for fin_state in states:
    count = m.generateTestCases(keys=(precondiciones+precondiciones),
                                targets=(ini_state+fin_state),
                                testcaseName=f"TRANSITION_{repr_transition(ini_state,fin_state,'push')}")
    if count > 0:
        found.append(f"found {count} testcases for transition {repr_transition(ini_state,fin_state,'push')}")
    else:
        found.append(f"found no testcases for transition {repr_transition(ini_state,fin_state,'push')}")
# Out:
# (level _is_sat_z3_call) took 0.010002851486206055 seconds (unsat)
# (level solver.can_be_true) took 0.015889406204223633 seconds
# (level state.can_be_true) took 0.016814708709716797 seconds
# (level _is_sat_z3_call) took 0.015017032623291016 seconds (unsat)
# (level solver.can_be_true) took 0.01963949203491211 seconds
# (level state.can_be_true) took 0.02001333236694336 seconds
# (level _is_sat_z3_call) took 0.010598421096801758 seconds (unsat)
# (level solver.can_be_true) took 0.014183759689331055 seconds
# (level state.can_be_true) took 0.014533042907714844 seconds
# (level _is_sat_z3_call) took 0.0056574344635009766 seconds (unsat)
# (level solver.can_be_true) took 0.008350849151611328 seconds
# (level state.can_be_true) took 0.00869441032409668 seconds
# (level _is_sat_z3_call) took 0.012804746627807617 seconds (unsat)
# (level solver.can_be_true) took 0.016497135162353516 seconds
# (level state.can_be_true) took 0.01683187484741211 seconds
# (level _is_sat_z3_call) took 0.010241270065307617 seconds (unsat)
# (level solver.can_be_true) took 0.013623714447021484 seconds
# (level state.can_be_true) took 0.013963460922241211 seconds
# (level _is_sat_z3_call) took 0.005753517150878906 seconds (unsat)
# (level solver.can_be_true) took 0.008480310440063477 seconds
# (level state.can_be_true) took 0.008816242218017578 seconds
# (level _is_sat_z3_call) took 0.014266490936279297 seconds (unsat)
# (level solver.can_be_true) took 0.018045902252197266 seconds
# (level state.can_be_true) took 0.018387794494628906 seconds
# (level _is_sat_z3_call) took 0.010396957397460938 seconds (unsat)
# (level solver.can_be_true) took 0.013907909393310547 seconds
# (level state.can_be_true) took 0.014242410659790039 seconds
# (level _is_sat_z3_call) took 0.005721092224121094 seconds (unsat)
# (level solver.can_be_true) took 0.008403778076171875 seconds
# (level state.can_be_true) took 0.008743524551391602 seconds
# (level _is_sat_z3_call) took 0.013695716857910156 seconds (unsat)
# (level solver.can_be_true) took 0.01871347427368164 seconds
# (level state.can_be_true) took 0.019059181213378906 seconds
# (level _is_sat_z3_call) took 0.010573148727416992 seconds (unsat)
# (level solver.can_be_true) took 0.013910770416259766 seconds
# (level state.can_be_true) took 0.014287471771240234 seconds
# (level _is_sat_z3_call) took 0.006915092468261719 seconds (unsat)
# (level solver.can_be_true) took 0.01007699966430664 seconds
# (level state.can_be_true) took 0.01043844223022461 seconds
# (level _is_sat_z3_call) took 0.013222217559814453 seconds (unsat)
# (level solver.can_be_true) took 0.01699542999267578 seconds
# (level state.can_be_true) took 0.017337560653686523 seconds
# (level _is_sat_z3_call) took 0.010212421417236328 seconds (unsat)
# (level solver.can_be_true) took 0.014195919036865234 seconds
# (level state.can_be_true) took 0.014585494995117188 seconds
# (level _is_sat_z3_call) took 0.005947589874267578 seconds (unsat)
# (level solver.can_be_true) took 0.00884103775024414 seconds
# (level state.can_be_true) took 0.009380817413330078 seconds
# (level _is_sat_z3_call) took 0.013502359390258789 seconds (unsat)
# (level solver.can_be_true) took 0.018122196197509766 seconds
# (level state.can_be_true) took 0.01847219467163086 seconds
# (level _is_sat_z3_call) took 0.010126113891601562 seconds (unsat)
# (level solver.can_be_true) took 0.013493537902832031 seconds
# (level state.can_be_true) took 0.013829469680786133 seconds
# (level _is_sat_z3_call) took 0.005688905715942383 seconds (unsat)
# (level solver.can_be_true) took 0.008355140686035156 seconds
# (level state.can_be_true) took 0.008690834045410156 seconds
# (level _is_sat_z3_call) took 0.013576030731201172 seconds (unsat)
# (level solver.can_be_true) took 0.02012348175048828 seconds
# (level state.can_be_true) took 0.020475387573242188 seconds
# (level _is_sat_z3_call) took 0.010837316513061523 seconds (unsat)
# (level solver.can_be_true) took 0.014724969863891602 seconds
# (level state.can_be_true) took 0.015083551406860352 seconds
# (level _is_sat_z3_call) took 0.019834280014038086 seconds (sat)
# (level solver.can_be_true) took 0.02366185188293457 seconds
# (level state.can_be_true) took 0.024078845977783203 seconds
# (level _is_sat_z3_call) took 0.02100658416748047 seconds (sat)
# (level solver.can_be_true) took 0.023680448532104492 seconds
# (level state.can_be_true) took 0.023702621459960938 seconds
# (level solver.can_be_true) took 0.00021386146545410156 seconds
# (level state.can_be_true) took 0.0002484321594238281 seconds
# (level _is_sat_z3_call) took 0.0019154548645019531 seconds (sat)
# (level get_value_in_batch) took 0.003993034362792969 seconds
# (level solve_one_n_batched) took 0.0041010379791259766 seconds
# (level _is_sat_z3_call) took 0.034716129302978516 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00038242340087890625 seconds
# (level _getvalue_all) took 0.0004589557647705078 seconds)
# (level get_value_in_batch) took 0.04444766044616699 seconds
# (level solve_one_n_batched) took 0.05015993118286133 seconds
# (level _is_sat_z3_call) took 0.0013873577117919922 seconds (sat)
# (level get_value_in_batch) took 0.004136562347412109 seconds
# (level solve_one_n_batched) took 0.0041446685791015625 seconds
# (level _is_sat_z3_call) took 0.0012090206146240234 seconds (sat)
# (level get_value_in_batch) took 0.003547191619873047 seconds
# (level solve_one_n_batched) took 0.0035851001739501953 seconds
# (level _is_sat_z3_call) took 0.2701680660247803 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0007679462432861328 seconds
# (level _getvalue_all) took 0.0008068084716796875 seconds)
# (level get_value_in_batch) took 0.2785637378692627 seconds
# (level solve_one_n_batched) took 0.280048131942749 seconds
# (level _is_sat_z3_call) took 0.0014400482177734375 seconds (sat)
# (level get_value_in_batch) took 0.0050389766693115234 seconds
# (level solve_one_n_batched) took 0.005047798156738281 seconds
# (level _is_sat_z3_call) took 0.001806497573852539 seconds (sat)
# (level get_value_in_batch) took 0.007958650588989258 seconds
# (level solve_one_n_batched) took 0.008022069931030273 seconds
# (level _is_sat_z3_call) took 0.001837015151977539 seconds (sat)
# (level get_value_in_batch) took 0.0051724910736083984 seconds
# (level solve_one_n_batched) took 0.005226612091064453 seconds
# (level _is_sat_z3_call) took 0.001382589340209961 seconds (sat)
# (level get_value_in_batch) took 0.004091501235961914 seconds
# (level solve_one_n_batched) took 0.004100799560546875 seconds
# (level _is_sat_z3_call) took 0.00128936767578125 seconds (sat)
# (level get_value_in_batch) took 0.0038976669311523438 seconds
# (level solve_one_n_batched) took 0.00393986701965332 seconds
# (level _is_sat_z3_call) took 0.0012378692626953125 seconds (sat)
# (level get_value_in_batch) took 0.004023551940917969 seconds
# (level solve_one_n_batched) took 0.004063606262207031 seconds
# (level _is_sat_z3_call) took 0.006035566329956055 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0012314319610595703 seconds
# (level _getvalue_all) took 0.0013339519500732422 seconds)
# (level get_value_in_batch) took 0.015262842178344727 seconds
# (level solve_one_n_batched) took 0.01990509033203125 seconds
# (level _is_sat_z3_call) took 0.0014948844909667969 seconds (sat)
# (level get_value_in_batch) took 0.004819393157958984 seconds
# (level solve_one_n_batched) took 0.005313396453857422 seconds
# (level _is_sat_z3_call) took 0.4583292007446289 seconds (sat)
# (level _getvalue_all_z3_call) took 0.09747552871704102 seconds
# (level _getvalue_all) took 0.09859061241149902 seconds)
# (level get_value_in_batch) took 8.21754765510559 seconds
# (level solve_one_n_batched) took 8.243034601211548 seconds
# (level _is_sat_z3_call) took 0.5008118152618408 seconds (sat)
# (level _getvalue_all_z3_call) took 0.19194602966308594 seconds
# (level _getvalue_all) took 0.19390130043029785 seconds)
# (level get_value_in_batch) took 17.62124752998352 seconds
# (level solve_one_n_batched) took 17.65387535095215 seconds
# (level _is_sat_z3_call) took 0.45615625381469727 seconds (sat)
# (level _getvalue_all_z3_call) took 0.06724834442138672 seconds
# (level _getvalue_all) took 0.067352294921875 seconds)
# (level get_value_in_batch) took 0.5552239418029785 seconds
# (level solve_one_n_batched) took 0.5563688278198242 seconds
# (level _is_sat_z3_call) took 0.003559589385986328 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0009188652038574219 seconds
# (level _getvalue_all) took 0.0010056495666503906 seconds)
# (level get_value_in_batch) took 0.016625642776489258 seconds
# (level solve_one_n_batched) took 0.017740726470947266 seconds
# (level _is_sat_z3_call) took 0.0032761096954345703 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0007224082946777344 seconds
# (level _getvalue_all) took 0.0007944107055664062 seconds)
# (level get_value_in_batch) took 0.014948368072509766 seconds
# (level solve_one_n_batched) took 0.016011476516723633 seconds
# (level _is_sat_z3_call) took 0.0034940242767333984 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0007760524749755859 seconds
# (level _getvalue_all) took 0.0008497238159179688 seconds)
# (level get_value_in_batch) took 0.014788627624511719 seconds
# (level solve_one_n_batched) took 0.01582503318786621 seconds
# (level _is_sat_z3_call) took 0.46297645568847656 seconds (sat)
# (level _getvalue_all_z3_call) took 0.001577615737915039 seconds
# (level _getvalue_all) took 0.0016503334045410156 seconds)
# (level get_value_in_batch) took 0.5105416774749756 seconds
# (level solve_one_n_batched) took 0.5115411281585693 seconds
# (level _is_sat_z3_call) took 0.4417402744293213 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0013110637664794922 seconds
# (level _getvalue_all) took 0.0013756752014160156 seconds)
# (level get_value_in_batch) took 0.47363924980163574 seconds
# (level solve_one_n_batched) took 0.47478389739990234 seconds
# (level _is_sat_z3_call) took 0.0028228759765625 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005953311920166016 seconds
# (level _getvalue_all) took 0.0006544589996337891 seconds)
# (level get_value_in_batch) took 0.014292716979980469 seconds
# (level solve_one_n_batched) took 0.015167474746704102 seconds
# (level _is_sat_z3_call) took 0.0027158260345458984 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005013942718505859 seconds
# (level _getvalue_all) took 0.0005543231964111328 seconds)
# (level get_value_in_batch) took 0.012714385986328125 seconds
# (level solve_one_n_batched) took 0.01356196403503418 seconds
# (level _is_sat_z3_call) took 0.002650737762451172 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005049705505371094 seconds
# (level _getvalue_all) took 0.0005609989166259766 seconds)
# (level get_value_in_batch) took 0.012501716613769531 seconds
# (level solve_one_n_batched) took 0.013316869735717773 seconds
# (level 3) took 27.98401427268982 seconds
# (level _is_sat_z3_call) took 0.0014467239379882812 seconds (sat)
# (level _getvalue_all_z3_call) took 8.559226989746094e-05 seconds
# (level _getvalue_all) took 0.00010561943054199219 seconds)
# (level get_value_in_batch) took 0.0032792091369628906 seconds
# (level solve_one_n_batched) took 0.0033321380615234375 seconds
# -Concrete value for initial_block : 0
# (level _is_sat_z3_call) took 0.005776643753051758 seconds (unsat)
# (level solver.can_be_true) took 0.008473634719848633 seconds
# (level state.can_be_true) took 0.008808612823486328 seconds
# (level _is_sat_z3_call) took 0.013345479965209961 seconds (unsat)
# (level solver.can_be_true) took 0.01758575439453125 seconds
# (level state.can_be_true) took 0.01792597770690918 seconds
# (level _is_sat_z3_call) took 0.010204792022705078 seconds (unsat)
# (level solver.can_be_true) took 0.013544321060180664 seconds
# (level state.can_be_true) took 0.013882160186767578 seconds
# (level _is_sat_z3_call) took 0.005724191665649414 seconds (unsat)
# (level solver.can_be_true) took 0.008705854415893555 seconds
# (level state.can_be_true) took 0.009064674377441406 seconds
# (level _is_sat_z3_call) took 0.013108015060424805 seconds (unsat)
# (level solver.can_be_true) took 0.016971111297607422 seconds
# (level state.can_be_true) took 0.017310142517089844 seconds
# (level _is_sat_z3_call) took 0.01143646240234375 seconds (unsat)
# (level solver.can_be_true) took 0.015272855758666992 seconds
# (level state.can_be_true) took 0.015630483627319336 seconds
# (level _is_sat_z3_call) took 0.00574040412902832 seconds (unsat)
# (level solver.can_be_true) took 0.008696317672729492 seconds
# (level state.can_be_true) took 0.009038686752319336 seconds
# (level _is_sat_z3_call) took 0.014072656631469727 seconds (unsat)
# (level solver.can_be_true) took 0.0184175968170166 seconds
# (level state.can_be_true) took 0.018759965896606445 seconds
# (level _is_sat_z3_call) took 0.010271787643432617 seconds (unsat)
# (level solver.can_be_true) took 0.013663530349731445 seconds
# (level state.can_be_true) took 0.014008045196533203 seconds
# (level _is_sat_z3_call) took 0.0060651302337646484 seconds (unsat)
# (level solver.can_be_true) took 0.008965015411376953 seconds
# (level state.can_be_true) took 0.009453058242797852 seconds
# (level _is_sat_z3_call) took 0.012896537780761719 seconds (unsat)
# (level solver.can_be_true) took 0.016675710678100586 seconds
# (level state.can_be_true) took 0.017017364501953125 seconds
# (level _is_sat_z3_call) took 0.010090827941894531 seconds (unsat)
# (level solver.can_be_true) took 0.013546943664550781 seconds
# (level state.can_be_true) took 0.013905763626098633 seconds
# (level _is_sat_z3_call) took 0.005688905715942383 seconds (unsat)
# (level solver.can_be_true) took 0.008466005325317383 seconds
# (level state.can_be_true) took 0.00881648063659668 seconds
# (level _is_sat_z3_call) took 0.013227462768554688 seconds (unsat)
# (level solver.can_be_true) took 0.017040014266967773 seconds
# (level state.can_be_true) took 0.017384767532348633 seconds
# (level _is_sat_z3_call) took 0.010248422622680664 seconds (unsat)
# (level solver.can_be_true) took 0.013538122177124023 seconds
# (level state.can_be_true) took 0.013881206512451172 seconds
# (level _is_sat_z3_call) took 0.005553722381591797 seconds (unsat)
# (level solver.can_be_true) took 0.008984565734863281 seconds
# (level state.can_be_true) took 0.009338617324829102 seconds
# (level _is_sat_z3_call) took 0.012796878814697266 seconds (unsat)
# (level solver.can_be_true) took 0.016574382781982422 seconds
# (level state.can_be_true) took 0.016913890838623047 seconds
# (level _is_sat_z3_call) took 0.010172843933105469 seconds (unsat)
# (level solver.can_be_true) took 0.013557910919189453 seconds
# (level state.can_be_true) took 0.013940811157226562 seconds
# (level _is_sat_z3_call) took 0.005652904510498047 seconds (unsat)
# (level solver.can_be_true) took 0.008335590362548828 seconds
# (level state.can_be_true) took 0.00867462158203125 seconds
# (level _is_sat_z3_call) took 0.013164281845092773 seconds (unsat)
# (level solver.can_be_true) took 0.017004728317260742 seconds
# (level state.can_be_true) took 0.017342805862426758 seconds
# (level _is_sat_z3_call) took 0.010210514068603516 seconds (unsat)
# (level solver.can_be_true) took 0.013520002365112305 seconds
# (level state.can_be_true) took 0.013858795166015625 seconds
# (level _is_sat_z3_call) took 0.0197603702545166 seconds (sat)
# (level solver.can_be_true) took 0.022919893264770508 seconds
# (level state.can_be_true) took 0.023259639739990234 seconds
# (level _is_sat_z3_call) took 0.018421649932861328 seconds (sat)
# (level solver.can_be_true) took 0.0206449031829834 seconds
# (level state.can_be_true) took 0.020653486251831055 seconds
# (level solver.can_be_true) took 0.0001583099365234375 seconds
# (level state.can_be_true) took 0.00017690658569335938 seconds
# (level _is_sat_z3_call) took 0.0013966560363769531 seconds (sat)
# (level get_value_in_batch) took 0.0034377574920654297 seconds
# (level solve_one_n_batched) took 0.003481149673461914 seconds
# (level _is_sat_z3_call) took 0.03343033790588379 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0003120899200439453 seconds
# (level _getvalue_all) took 0.00034165382385253906 seconds)
# (level get_value_in_batch) took 0.0419461727142334 seconds
# (level solve_one_n_batched) took 0.04698014259338379 seconds
# (level _is_sat_z3_call) took 0.0013773441314697266 seconds (sat)
# (level get_value_in_batch) took 0.003999233245849609 seconds
# (level solve_one_n_batched) took 0.0040073394775390625 seconds
# (level _is_sat_z3_call) took 0.0012183189392089844 seconds (sat)
# (level get_value_in_batch) took 0.003439664840698242 seconds
# (level solve_one_n_batched) took 0.003476858139038086 seconds
# (level _is_sat_z3_call) took 0.2685678005218506 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0007412433624267578 seconds
# (level _getvalue_all) took 0.0007731914520263672 seconds)
# (level get_value_in_batch) took 0.2773003578186035 seconds
# (level solve_one_n_batched) took 0.27878403663635254 seconds
# (level _is_sat_z3_call) took 0.0014312267303466797 seconds (sat)
# (level get_value_in_batch) took 0.005059480667114258 seconds
# (level solve_one_n_batched) took 0.005068063735961914 seconds
# (level _is_sat_z3_call) took 0.0012545585632324219 seconds (sat)
# (level get_value_in_batch) took 0.004030942916870117 seconds
# (level solve_one_n_batched) took 0.004069328308105469 seconds
# (level _is_sat_z3_call) took 0.0013222694396972656 seconds (sat)
# (level get_value_in_batch) took 0.0038917064666748047 seconds
# (level solve_one_n_batched) took 0.003927946090698242 seconds
# (level _is_sat_z3_call) took 0.0012500286102294922 seconds (sat)
# (level get_value_in_batch) took 0.003802061080932617 seconds
# (level solve_one_n_batched) took 0.0038101673126220703 seconds
# (level _is_sat_z3_call) took 0.00122833251953125 seconds (sat)
# (level get_value_in_batch) took 0.0037555694580078125 seconds
# (level solve_one_n_batched) took 0.0037925243377685547 seconds
# (level _is_sat_z3_call) took 0.001222848892211914 seconds (sat)
# (level get_value_in_batch) took 0.0037238597869873047 seconds
# (level solve_one_n_batched) took 0.0037610530853271484 seconds
# (level _is_sat_z3_call) took 0.005647897720336914 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0010161399841308594 seconds
# (level _getvalue_all) took 0.0010967254638671875 seconds)
# (level get_value_in_batch) took 0.013113975524902344 seconds
# (level solve_one_n_batched) took 0.017604589462280273 seconds
# (level _is_sat_z3_call) took 0.0013267993927001953 seconds (sat)
# (level get_value_in_batch) took 0.00429224967956543 seconds
# (level solve_one_n_batched) took 0.004815340042114258 seconds
# (level _is_sat_z3_call) took 0.4631626605987549 seconds (sat)
# (level _getvalue_all_z3_call) took 0.06913256645202637 seconds
# (level _getvalue_all) took 0.07009363174438477 seconds)
# (level get_value_in_batch) took 8.118606805801392 seconds
# (level solve_one_n_batched) took 8.141496419906616 seconds
# (level _is_sat_z3_call) took 0.5057229995727539 seconds (sat)
# (level _getvalue_all_z3_call) took 0.26711368560791016 seconds
# (level _getvalue_all) took 0.269092321395874 seconds)
# (level get_value_in_batch) took 17.557870388031006 seconds
# (level solve_one_n_batched) took 17.588926792144775 seconds
# (level _is_sat_z3_call) took 0.4304659366607666 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0012896060943603516 seconds
# (level _getvalue_all) took 0.0013535022735595703 seconds)
# (level get_value_in_batch) took 0.4644310474395752 seconds
# (level solve_one_n_batched) took 0.4656217098236084 seconds
# (level _is_sat_z3_call) took 0.0027735233306884766 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005042552947998047 seconds
# (level _getvalue_all) took 0.0005593299865722656 seconds)
# (level get_value_in_batch) took 0.014222145080566406 seconds
# (level solve_one_n_batched) took 0.015274763107299805 seconds
# (level _is_sat_z3_call) took 0.0025894641876220703 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0004889965057373047 seconds
# (level _getvalue_all) took 0.0005748271942138672 seconds)
# (level get_value_in_batch) took 0.012871980667114258 seconds
# (level solve_one_n_batched) took 0.01389455795288086 seconds
# (level _is_sat_z3_call) took 0.0026335716247558594 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00048351287841796875 seconds
# (level _getvalue_all) took 0.0005381107330322266 seconds)
# (level get_value_in_batch) took 0.012726306915283203 seconds
# (level solve_one_n_batched) took 0.013726472854614258 seconds
# (level _is_sat_z3_call) took 0.4330120086669922 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0014731884002685547 seconds
# (level _getvalue_all) took 0.0015425682067871094 seconds)
# (level get_value_in_batch) took 0.47997522354125977 seconds
# (level solve_one_n_batched) took 0.4809558391571045 seconds
# (level _is_sat_z3_call) took 0.4281635284423828 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0012784004211425781 seconds
# (level _getvalue_all) took 0.0013418197631835938 seconds)
# (level get_value_in_batch) took 0.459075927734375 seconds
# (level solve_one_n_batched) took 0.4601631164550781 seconds
# (level _is_sat_z3_call) took 0.002786874771118164 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005035400390625 seconds
# (level _getvalue_all) took 0.0005590915679931641 seconds)
# (level get_value_in_batch) took 0.014154434204101562 seconds
# (level solve_one_n_batched) took 0.015093564987182617 seconds
# (level _is_sat_z3_call) took 0.002612590789794922 seconds (sat)
# (level _getvalue_all_z3_call) took 0.0005202293395996094 seconds
# (level _getvalue_all) took 0.0005750656127929688 seconds)
# (level get_value_in_batch) took 0.012799739837646484 seconds
# (level solve_one_n_batched) took 0.01369333267211914 seconds
# (level _is_sat_z3_call) took 0.0026178359985351562 seconds (sat)
# (level _getvalue_all_z3_call) took 0.00048422813415527344 seconds
# (level _getvalue_all) took 0.0005390644073486328 seconds)
# (level get_value_in_batch) took 0.012545585632324219 seconds
# (level solve_one_n_batched) took 0.013416528701782227 seconds
# (level 3) took 27.652384996414185 seconds
# (level _is_sat_z3_call) took 0.001522064208984375 seconds (sat)
# (level _getvalue_all_z3_call) took 8.606910705566406e-05 seconds
# (level _getvalue_all) took 0.00010609626770019531 seconds)
# (level get_value_in_batch) took 0.0033359527587890625 seconds
# (level solve_one_n_batched) took 0.003388643264770508 seconds
# -Concrete value for initial_block : 0

# %%
for line in found:
    print(line)
# Out:
# found no testcases for transition _push_top_isEmpty->push->vacio
# found no testcases for transition _push_top_isEmpty->push->_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_top
# found no testcases for transition _push_top_isEmpty->push->_top_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_pop
# found no testcases for transition _push_top_isEmpty->push->_pop_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_pop_top
# found 1 testcases for transition _push_top_isEmpty->push->_pop_top_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_push
# found no testcases for transition _push_top_isEmpty->push->_push_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_push_top
# found no testcases for transition _push_top_isEmpty->push->_push_top_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_push_pop
# found no testcases for transition _push_top_isEmpty->push->_push_pop_isEmpty
# found no testcases for transition _push_top_isEmpty->push->_push_pop_top
# found 1 testcases for transition _push_top_isEmpty->push->_push_pop_top_isEmpty

# %%
m.take_snapshot()
m.callContractFunction("pop")
call_pre()
# Out:
# (level _is_sat_z3_call) took 0.02052927017211914 seconds (sat)
# (level _getvalue_z3_call) took 0.0003535747528076172 seconds
# (level _is_sat_z3_call) took 0.0005738735198974609 seconds (sat)
# (level _getvalue_z3_call) took 0.00018453598022460938 seconds
# (level _is_sat_z3_call) took 0.00047016143798828125 seconds (sat)
# (level _getvalue_z3_call) took 0.0002498626708984375 seconds
# (level _is_sat_z3_call) took 0.00026607513427734375 seconds (unsat)
# (level _is_sat_z3_call) took 0.24110102653503418 seconds (sat)
# (level _getvalue_z3_call) took 0.014252185821533203 seconds
# (level _is_sat_z3_call) took 0.0029518604278564453 seconds (sat)
# (level _getvalue_z3_call) took 0.0007410049438476562 seconds
# (level _is_sat_z3_call) took 0.011744976043701172 seconds (sat)
# (level _getvalue_z3_call) took 0.002877473831176758 seconds
# (level _is_sat_z3_call) took 0.0023581981658935547 seconds (unsat)
# (level _is_sat_z3_call) took 0.405059814453125 seconds (sat)
# (level _getvalue_z3_call) took 0.0037970542907714844 seconds
# (level _is_sat_z3_call) took 0.009447574615478516 seconds (sat)
# (level _getvalue_z3_call) took 0.0034084320068359375 seconds
# (level _is_sat_z3_call) took 0.04465150833129883 seconds (sat)
# (level _getvalue_z3_call) took 0.005600452423095703 seconds
# (level _is_sat_z3_call) took 0.02881026268005371 seconds (unsat)
# (level _is_sat_z3_call) took 0.30223608016967773 seconds (sat)
# (level _is_sat_z3_call) took 0.25911545753479004 seconds (sat)
# (level _is_sat_z3_call) took 0.28504395484924316 seconds (sat)
# (level _is_sat_z3_call) took 1.0989630222320557 seconds (sat)
# (level _is_sat_z3_call) took 0.4167966842651367 seconds (sat)
# (level _is_sat_z3_call) took 0.5111005306243896 seconds (sat)
# (level _is_sat_z3_call) took 0.8001875877380371 seconds (sat)
# (level _is_sat_z3_call) took 4.225488185882568 seconds (sat)
# (level _is_sat_z3_call) took 4.5024094581604 seconds (sat)
# (level _is_sat_z3_call) took 0.526167631149292 seconds (sat)
# (level _is_sat_z3_call) took 0.7186825275421143 seconds (sat)
# (level _is_sat_z3_call) took 4.385434627532959 seconds (sat)
# (level _is_sat_z3_call) took 0.5777676105499268 seconds (sat)
# (level _is_sat_z3_call) took 0.8315236568450928 seconds (sat)
# (level _is_sat_z3_call) took 4.382282972335815 seconds (sat)
# (level _is_sat_z3_call) took 0.5843102931976318 seconds (sat)
# (level _is_sat_z3_call) took 0.8722753524780273 seconds (sat)
# (level _is_sat_z3_call) took 4.684130907058716 seconds (sat)

# %%
ini_states = [(1,1),(0,1)] #_push_pop , #_pop
found = []
for ini_state in ini_states:
    for fin_state in states:
        count = m.generateTestCases(keys=(precondiciones+precondiciones),
                                    targets=(ini_state+fin_state),
                                    testcaseName=f"TRANSITION_{repr_transition(ini_state,fin_state,'pop')}")
        if count > 0:
            found.append(f"found {count} testcases for transition {repr_transition(ini_state,fin_state,'pop')}")
        else:
            found.append(f"found no testcases for transition {repr_transition(ini_state,fin_state,'pop')}")

# %%
for line in found:
    print(line)
